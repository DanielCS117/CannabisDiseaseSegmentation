# %% [markdown]
# Main Script

# %% [markdown]
# 6 Clases

# %% [markdown]
# # Data Loading and Checking

# %%
import torch
import torchvision
import torch.utils.data as data
import torchvision.utils as utils
import torch.nn as nn
import torch.nn.functional as F
import skimage.io as io
from torch.utils.data import Dataset, DataLoader
from torchvision import io, transforms
import torchvision.transforms.functional as TF
from tqdm.auto import tqdm
import torchvision.datasets as dset
import torchvision.transforms as T
from torchvision import models
import os
import numpy as np
from PIL import Image, ImageOps, ImageFilter
from pathlib import Path
import random
from pycocotools.coco import COCO
from pycocotools import mask as maskUtils
import pycocotools
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ROOT PATH

# %%
ROOT = Path().resolve()     # Root path
DB_DIR = ROOT / 'Database' 
TRAIN_IMG_DIR = DB_DIR / 'train' / 'images'
TEST_IMG_DIR = DB_DIR / 'test' / 'images'
TRAIN_ANN_DIR = DB_DIR / 'train' /'annotations' / 'train_data1024.json'
TEST_ANN_DIR = DB_DIR / 'test' /'annotations' / 'test_data1024.json'

# %%
TEST_IMG_DIR
# Out:
# WindowsPath('E:/OneDrive/Tesis/Database/test/images')

# %% [markdown]
# ## ANNOTATION FILE PARAMETERS

# %%
ann_File_train = TRAIN_ANN_DIR
coco_file_train = COCO(ann_File_train)
ann_File_test = TEST_ANN_DIR
coco_file_test = COCO(ann_File_test)
# Out:
# loading annotations into memory...
# Done (t=0.38s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!

# %%
ann_File_train
# Out:
# WindowsPath('E:/OneDrive/Tesis/Database/train/annotations/train_data1024.json')

# %%
#   Verifying the train JSON file keys

dataset_view_train = coco_file_train.dataset
print("dataset_view_train type: ", type(dataset_view_train))
print("dataset_view_train.keys(): ", dataset_view_train.keys())
# Out:
# dataset_view_train type:  <class 'dict'>
# dataset_view_train.keys():  dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])

# %%
#   Verifying the train JSON file subkeys

dataset_view_train = coco_file_train.dataset
print("dataset_view_train type: ", type(dataset_view_train))
print("dataset_view_train.keys(): ", dataset_view_train.keys(), "\n")

dataset_view_train_info = dataset_view_train["info"]
print("dataset_view_train_info: ", "Type: ", type(dataset_view_train_info), dataset_view_train_info)
dataset_view_train_licenses = dataset_view_train["licenses"]
print("dataset_view_train_licenses: ", "Type: ", type(dataset_view_train_licenses), dataset_view_train_licenses, "\n")
dataset_view_train_images = dataset_view_train["images"]
print("dataset_view_train_images: ", "Type: ", type(dataset_view_train_images))
print("dataset_view_train_images keys: ", dataset_view_train_images[0].keys(), "\n")
dataset_view_train_annotations = dataset_view_train["annotations"]
print("dataset_view_train_annotations: ", "Type: ", type(dataset_view_train_annotations))
print("dataset_view_train_annotations keys: ", dataset_view_train_annotations[0].keys(), "\n")

dataset_view_train_categories = dataset_view_train["categories"]
print("dataset_view_train_categories: ", "Type: ", type(dataset_view_train_categories))
print("dataset_view_train_categories keys: ", dataset_view_train_categories[0].keys())
# Out:
# dataset_view_train type:  <class 'dict'>
# dataset_view_train.keys():  dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])
#
# dataset_view_train_info:  Type:  <class 'dict'> {'description': '', 'url': 'None', 'version': '1.0', 'year': 2022}
# dataset_view_train_licenses:  Type:  <class 'list'> []
#
# dataset_view_train_images:  Type:  <class 'list'>
# dataset_view_train_images keys:  dict_keys(['license', 'file_name', 'width', 'height', 'id', 'url', 'date_captured'])
#
# dataset_view_train_annotations:  Type:  <class 'list'>
# dataset_view_train_annotations keys:  dict_keys(['area', 'bbox', 'category_id', 'id', 'image_id', 'iscrowd', 'segmentation'])
#
# dataset_view_train_categories:  Type:  <class 'list'>
# dataset_view_train_categories keys:  dict_keys(['color', 'name', 'id', 'supercategory'])

# %%
#   Verifying validation JSON file keys

dataset_view_test = coco_file_test.dataset
print("dataset_view_test type: ", type(dataset_view_test))
print("dataset_view_test.keys(): ", dataset_view_test.keys())
# Out:
# dataset_view_test type:  <class 'dict'>
# dataset_view_test.keys():  dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])

# %%
#   Verifying validation JSON file subkeys

dataset_view_test = coco_file_test.dataset
print("dataset_view_test type: ", type(dataset_view_test))
print("dataset_view_test.keys(): ", dataset_view_test.keys(), "\n")

dataset_view_test_info = dataset_view_test["info"]
print("dataset_view_test_info: ", "Type: ", type(dataset_view_test_info), dataset_view_test_info)
dataset_view_test_licenses = dataset_view_test["licenses"]
print("dataset_view_test_licenses: ", "Type: ", type(dataset_view_test_licenses), dataset_view_test_licenses, "\n")
dataset_view_test_images = dataset_view_test["images"]
print("dataset_view_test_images: ", "Type: ", type(dataset_view_test_images))
print("dataset_view_test_images keys: ", dataset_view_test_images[0].keys(), "\n")
dataset_view_test_annotations = dataset_view_test["annotations"]
print("dataset_view_test_annotations: ", "Type: ", type(dataset_view_test_annotations))
print("dataset_view_test_annotations keys: ", dataset_view_test_annotations[0].keys(), "\n")

dataset_view_test_categories = dataset_view_test["categories"]
print("dataset_view_test_categories: ", "Type: ", type(dataset_view_test_categories))
print("dataset_view_test_categories keys: ", dataset_view_test_categories[0].keys())
# Out:
# dataset_view_test type:  <class 'dict'>
# dataset_view_test.keys():  dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])
#
# dataset_view_test_info:  Type:  <class 'dict'> {'description': '', 'url': 'None', 'version': '1.0', 'year': 2022}
# dataset_view_test_licenses:  Type:  <class 'list'> []
#
# dataset_view_test_images:  Type:  <class 'list'>
# dataset_view_test_images keys:  dict_keys(['license', 'file_name', 'width', 'height', 'id', 'url', 'date_captured'])
#
# dataset_view_test_annotations:  Type:  <class 'list'>
# dataset_view_test_annotations keys:  dict_keys(['area', 'bbox', 'category_id', 'id', 'image_id', 'iscrowd', 'segmentation'])
#
# dataset_view_test_categories:  Type:  <class 'list'>
# dataset_view_test_categories keys:  dict_keys(['color', 'name', 'id', 'supercategory'])

# %%
len(dataset_view_test_annotations)
# Out:
# 1871

# %% [markdown]
# ## DATA DEFINITION

# %%
# Defining categories, objects and areas per categories. Train images ID: 0 to 9. Test Images ID: 15 to 19
 
import json

split = TEST_ANN_DIR

with open(split, 'r') as f:
    dataset = json.load(f)

if split == TRAIN_ANN_DIR:
    partition = 'Train'
elif split == TEST_ANN_DIR: 
    partition = 'Test'
    
# Load image by ID
image_id = 15
print("Image ID: ", image_id)


annotations = [annotation for annotation in dataset['annotations'] if annotation['image_id'] == image_id]
category_counts = {}

# Object count (by area)
total_count = 0
total_area = 1024*1024
for annotation in annotations:
    category_id = annotation['category_id']
    if category_id not in category_counts:
        category_counts[category_id] = {'count': 0, 'area': 0}
    category_counts[category_id]['count'] += 1
    category_counts[category_id]['area'] += annotation['area']
    total_count += 1


# Category mapping
category_mapping = {category['id']: category['name'] for category in dataset['categories']}
print(f'{partition} partition database distribution')
for category_id, counts in category_counts.items():
    category = category_mapping[category_id]
    count = counts['count']
    area = counts['area']
    print(f"Category: {category}, number of objects: {count}, total area: {area}", "pixels")

print(f"Total number of objects in the image: {total_count}")
print(f"Total image area: {total_area}", "pixels")
# Out:
# Image ID:  15
# Test partition database distribution
# Category: healthy, number of objects: 36, total area: 579672.5 pixels
# Category: botritisone, number of objects: 21, total area: 18741.5 pixels
# Category: botritistwo, number of objects: 27, total area: 8053.0 pixels
# Category: botritisthree, number of objects: 20, total area: 6720.5 pixels
# Category: defnutrition, number of objects: 87, total area: 214038.0 pixels
# Category: background, number of objects: 480, total area: 260125.5 pixels
# Total number of objects in the image: 671
# Total image area: 1048576 pixels

# %%
import json

split = TRAIN_ANN_DIR
with open(split, 'r') as f:
    dataset = json.load(f)

if split == TRAIN_ANN_DIR:
    partition = 'Train'
elif split == TEST_ANN_DIR: 
    partition = 'Test'

category_areas = {}
for annotation in dataset['annotations']:
    category_id = annotation['category_id']
    area = annotation['area']

    if category_id not in category_areas:
        category_areas[category_id] = 0

    category_areas[category_id] += area


category_mapping = {category['id']: category['name'] for category in dataset['categories']}
print(f'Total area by category in {partition} partition:')
for category_id, area in category_areas.items():
    category = category_mapping[category_id]
    print(f"Category: {category}, total area: {area}")
# Out:
# Total area by category in Train partition:
# Category: healthy, total area: 5370866.5
# Category: botritisone, total area: 1045312.5
# Category: botritistwo, total area: 50682.5
# Category: botritisthree, total area: 103966.5
# Category: defnutrition, total area: 1027961.5
# Category: background, total area: 3109495.0

# %% [markdown]
# ## JSON FILE KEYS

# %%
with open(TRAIN_ANN_DIR, 'r') as f:
    data = json.load(f)
annotation_keys = data['annotations'][0].keys()
categories_keys = data['categories'][0].keys()

print("Main keys: ", data.keys())
print("Images keys:", data['images'][0].keys())
print("Annotations keys:",annotation_keys)
print("Categories keys:",categories_keys)

categories_data = data['categories']
print(categories_data)
# Out:
# Main keys:  dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])
# Images keys: dict_keys(['license', 'file_name', 'width', 'height', 'id', 'url', 'date_captured'])
# Annotations keys: dict_keys(['area', 'bbox', 'category_id', 'id', 'image_id', 'iscrowd', 'segmentation'])
# Categories keys: dict_keys(['color', 'name', 'id', 'supercategory'])
# [{'color': '#690ac1', 'name': 'healthy', 'id': 1, 'supercategory': 'healthy'}, {'color': '#ff1e00', 'name': 'botritisone', 'id': 2, 'supercategory': 'botritisone'}, {'color': '#e52bba', 'name': 'botritistwo', 'id': 3, 'supercategory': 'botritistwo'}, {'color': '#2600ff', 'name': 'botritisthree', 'id': 4, 'supercategory': 'botritisthree'}, {'color': '#00c203', 'name': 'defnutrition', 'id': 5, 'supercategory': 'defnutrition'}, {'color': '#fbff00', 'name': 'background', 'id': 0, 'supercategory': 'background'}]

# %% [markdown]
# # DATALOADER SS UNET Train

# %% [markdown]
# SCRIPT FOR CREATE THE DATALOADER OBJECTS

# %%
import os
import numpy as np
import random
import torch
import torchvision
import torchvision.utils as utils
from torchvision import io, transforms
import torchvision.transforms.functional as TF
import torchvision.transforms as T
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import segmentation_models_pytorch as smp
import torch.optim as optim
from PIL import Image, ImageOps, ImageFilter
from pycocotools.coco import COCO
from tqdm.auto import tqdm
from pycocotools.coco import COCO
import json
import matplotlib.pyplot as plt
from pathlib import Path

# %matplotlib inline

ROOT = Path().resolve()     # Root path
DB_DIR = ROOT / 'Database' 
TRAIN_ANN_DIR = DB_DIR / 'train' /'annotations' / 'train_data1024.json'
TEST_ANN_DIR = DB_DIR / 'test' /'annotations' / 'test_data1024.json'

class CocoSemSegUNET(data.Dataset):
    """
    PyTorch Dataset for semantic segmentation using COCO-style annotations.

    This dataset handles six semantic classes of plant conditions and computes
    class frequencies and weights based on annotated areas for training with 
    class imbalance compensation.

    Attributes:
        coco (COCO): COCO annotation API object.
        image_ids (list): List of image IDs from COCO annotations.
        transform (callable): Transformations to apply to the images.
        split (str): Dataset split ("train" or "test").
        class_names (list): List of class names.
        num_classes (int): Number of classes.
        class_frequencies (np.ndarray): Frequency of each class.
        class_weights (torch.Tensor): Computed weight for each class.
    """
    def __init__(self, coco_json_file, split, transform=None):
        """
        Initialize the dataset.

        Args:
            coco_json_file (str): Path to the COCO annotation JSON file.
            split (str): Dataset split ("train" or "test").
            transform (callable, optional): Image transformation function.
        """
        self.coco = COCO(coco_json_file)
        self.image_ids = self.coco.getImgIds()
        self.transform = transform
        self.split = split
        self.class_names = ['background', 'healthy', 'botritisone', 'botritistwo', 'botritisthree', 'defnutrition']
        self.num_classes = len(self.class_names)
        self.class_frequencies = self._calculate_class_frequencies()
        self.class_weights = self._calculate_class_weights()

    def _calculate_class_frequencies(self):
        """
        Calculates the pixel area covered by each class across all images.

        Returns:
            np.ndarray: Array of class frequencies (total area per class).
        """
        class_frequencies = np.zeros(self.num_classes)  

        for image_id in self.image_ids:
            annotation_ids = self.coco.getAnnIds(imgIds=image_id)
            annotations = self.coco.loadAnns(annotation_ids)

            for ann in annotations:
                category_id = ann['category_id']
                if category_id in range(0,6):
                    class_frequencies[category_id] += ann['area']
        
        for category_id, frequency in enumerate(class_frequencies):
          print(f"Category ID: {category_id}, Frequency: {frequency}")

        return class_frequencies

    def _calculate_class_weights(self):
        """
        Computes class weights inversely proportional to class area frequency.

        Returns:
            torch.Tensor: Normalized class weights as a tensor.
        """
        total_samples = np.sum(self.class_frequencies)
        class_areas = np.zeros_like(self.class_frequencies)

        for image_id in self.image_ids:
            annotation_ids = self.coco.getAnnIds(imgIds=image_id)
            annotations = self.coco.loadAnns(annotation_ids)

            for ann in annotations:
                category_id = ann['category_id']
                if category_id in range(0,6):
                    area = ann['area']
                    class_areas[category_id] += area

        class_weights = 1.0 / (6.0*class_areas / total_samples) 
        class_weights /= np.max(class_weights)  
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        class_weights = torch.tensor(class_weights, dtype=torch.float32, device=device)

        return class_weights

    def __getitem__(self, index):
        """
        Retrieves the transformed image and multi-channel binary mask for a given index.

        Args:
            index (int): Index of the image to load.

        Returns:
            tuple: Transformed image (Tensor) and masks (Tensor).
        """
        image_id = self.image_ids[index]
        image_info = self.coco.loadImgs(image_id)[0]

        if self.split == 'train':
            image_dir = DB_DIR / 'train' / 'images'
        else:
            image_dir = DB_DIR / 'test' / 'images'
        
        image_path = image_dir / image_info['file_name']
        image = Image.open(image_path).convert('RGB')
        annotation_ids = self.coco.getAnnIds(imgIds=image_id)
        annotations = self.coco.loadAnns(annotation_ids)
        masks = self._generate_masks(annotations, image.size)

        if self.transform is not None:
            image = self.transform(image)

        return image, masks

    def __len__(self):
        """
        Returns the number of images in the dataset.

        Returns:
            int: Length of the dataset.
        """
        return len(self.image_ids)


    def _generate_masks(self, annotations, image_size):
        """
        Generates binary masks for all defined classes based on annotations.

        Args:
            annotations (list): List of annotations for a single image.
            image_size (tuple): (width, height) of the image.

        Returns:
            torch.Tensor: Multi-channel mask tensor with one channel per class.
        """
        num_classes = self.num_classes  
        masks = torch.zeros(num_classes, *image_size)  
        category_counts = {category_id: 0 for category_id in range(num_classes)}  
        total_objects = 0  

        for ann in annotations:
            category_id = ann['category_id']
            if category_id in range(0,6):
                mask = self.coco.annToMask(ann)

            # Get binary mask per channel
                mask_tensor = torch.from_numpy(mask).float()
                binary_mask = (mask_tensor > 0).float()
                masks[category_id] += binary_mask
                category_counts[category_id] += 1
                total_objects += 1

        print("Count per category:", category_counts)
        print("Total number of objects:", total_objects)

        return masks

    def get_class_weights(self):
        """
        Returns the computed class weights.

        Returns:
            torch.Tensor: Class weights tensor.
        """
        return self.class_weights

def custom_collate_fn(batch):
    """
    Custom collate function to batch images and masks for DataLoader.

    Args:
        batch (list): List of (image, mask) tuples.

    Returns:
        tuple: Batched images and masks.
    """
    images, masks = zip(*batch)
    if isinstance(images[0], torch.Tensor):
        images = torch.stack(images, dim=0)
    else:
        image_transform = transforms.ToTensor()
        images = [image_transform(image) for image in images]
        images = torch.stack(images, dim=0)

    masks = torch.stack(masks, dim=0)
    return images, masks

"""
Dataset and DataLoader setup for training and testing.

- Defines common image transformations.
- Initializes training and testing datasets using COCO-style annotations.
- Creates DataLoaders with a custom collate function.
- Prints class frequencies and computed class weights for both splits.
"""

split1 = "train"
coco_json_file1 = str(TRAIN_ANN_DIR)
split2 = "test"
coco_json_file2 = str(TEST_ANN_DIR)

transform = transforms.Compose([
    transforms.Resize((1024, 1024)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


# DataSet and DataLoader creation
dataset_train = CocoSemSegUNET(coco_json_file1, split1, transform=transform)
dataloader_train = data.DataLoader(dataset_train, batch_size=1, shuffle=True, collate_fn=custom_collate_fn)
dataset_test = CocoSemSegUNET(coco_json_file2, split2, transform=transform)
dataloader_test = data.DataLoader(dataset_test, batch_size=1, shuffle=True, collate_fn=custom_collate_fn)
dataset_used = "RAW 6 Classes"

class_frequencies_train = dataset_train._calculate_class_frequencies()
class_weights_train = dataset_train._calculate_class_weights()
print("Class Frequencies Train:", class_frequencies_train)
print("Class Weights Train:", class_weights_train)

class_frequencies_test = dataset_test._calculate_class_frequencies()
class_weights_test = dataset_test._calculate_class_weights()
print("Class Frequencies Test:", class_frequencies_test)
print("Class Weights Test:", class_weights_test)

# %% [markdown]
# # SAMPLE BATCHES AND WEIGHTS

# %% [markdown]
# Verifyng batches (structure, objects and plotting)

# %%
batch = next(iter(dataloader_train))
# Out:
# Count per category: {0: 435, 1: 53, 2: 102, 3: 16, 4: 16, 5: 124}
# Total number of objects: 746

# %%
batch_test = next(iter(dataloader_test))
# Out:
# Count per category: {0: 265, 1: 72, 2: 23, 3: 29, 4: 3, 5: 61}
# Total number of objects: 453

# %%
batch_images, batch_masks = batch
batch_images_t, batch_masks_t = batch_test

print("imagen.shape: ", batch_images.shape)
print("masks.shape: ", batch_masks.shape)
print("imagen_t.shape: ", batch_images_t.shape)
print("masks_t.shape: ", batch_masks_t.shape)
# Out:
# imagen.shape:  torch.Size([1, 3, 1024, 1024])
# masks.shape:  torch.Size([1, 6, 1024, 1024])
# imagen_t.shape:  torch.Size([1, 3, 1024, 1024])
# masks_t.shape:  torch.Size([1, 6, 1024, 1024])

# %%
class_frequencies_train = dataset_train._calculate_class_frequencies()
class_weights_train = dataset_train._calculate_class_weights()
print("Class Frequencies Train:", class_frequencies_train)
print("Class Weights Train:", class_weights_train)

class_frequencies_test = dataset_test._calculate_class_frequencies()
class_weights_test = dataset_test._calculate_class_weights()
print("Class Frequencies Test:", class_frequencies_test)
print("Class Weights Test:", class_weights_test)
# Out:
# Category ID: 0, Frequency: 3109495.0
# Category ID: 1, Frequency: 5370866.5
# Category ID: 2, Frequency: 1045312.5
# Category ID: 3, Frequency: 50682.5
# Category ID: 4, Frequency: 103966.5
# Category ID: 5, Frequency: 1027961.5
# Class Frequencies Train: [3109495.  5370866.5 1045312.5   50682.5  103966.5 1027961.5]
# Class Weights Train: tensor([0.0163, 0.0094, 0.0485, 1.0000, 0.4875, 0.0493], device='cuda:0')
# Category ID: 0, Frequency: 1265239.0
# Category ID: 1, Frequency: 1762823.0
# Category ID: 2, Frequency: 440249.5
# Category ID: 3, Frequency: 98588.5
# Category ID: 4, Frequency: 23788.0
# Category ID: 5, Frequency: 749277.5
# Class Frequencies Test: [1265239.  1762823.   440249.5   98588.5   23788.   749277.5]
# Class Weights Test: tensor([0.0188, 0.0135, 0.0540, 0.2413, 1.0000, 0.0317], device='cuda:0')

# %% [markdown]
# Class Weights: [0.01629927 0.00943656 0.0484855  1.         0.48748876 0.04930389]

# %% [markdown]
# ## Batch plot

# %%
mask = batch_masks[0]

for class_index in range(mask.shape[0]):
    print(class_index)
    mask_channel_np = mask[class_index].numpy()
    plt.imshow(mask_channel_np, cmap='gray')
    plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
image_toshow = batch_images[0]
mask_toshow = batch_masks[0]

plt.subplot(1, 2, 1)
plt.imshow(image_toshow.permute(1, 2, 0))
plt.axis('off')
plt.title('Imagen')

for class_index in range(mask_toshow.shape[0]):
    
    mask_channel = mask[class_index].numpy()
    
    plt.subplot(1, 2, 1)
    plt.imshow(image_toshow.permute(1, 2, 0))
    plt.axis('off')
    plt.title('Image')
    
    plt.subplot(1, 2, 2)
    plt.imshow(mask_channel, cmap='gray')
    plt.axis('off')
    plt.title('Mask (Class {})'.format(class_index))

    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
mask = batch_masks[0]

color_map = {
    0: (0, 0, 0),           # Background (Negro)
    1: (0, 255, 0),         # Healthy (verde)
    2: (255, 0, 0),         # Botrytis One (rojo)
    3: (0, 0, 255),         # Botrytis Two (azul)
    4: (255, 0, 255),       # Botrytis Three (amarillo)
    5: (255, 255, 0)        # Defnutrition (magenta)
}

combined_mask = np.zeros((mask.shape[1], mask.shape[2], 3), dtype=np.float64)

for class_index in range(mask.shape[0]):
    mask_channel = mask[class_index].numpy()
    color = color_map[class_index]
    combined_mask += np.expand_dims(mask_channel, axis=2).astype(np.float64) * np.array(color)

combined_mask = np.uint8(np.round(combined_mask))
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# Plotting
ax[0].imshow(batch_images[0].permute(1, 2, 0).numpy())
ax[0].axis('off')
ax[0].set_title('Image')

# Full mask plotting
ax[1].imshow(combined_mask)
ax[1].axis('off')
ax[1].set_title('Combination mask')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # PLOTTING FROM IMAGE ID

# %%
import cv2
image_id = 5
annotations = [annotation for annotation in dataset_view_train['annotations'] if annotation['image_id'] == image_id]

if len(annotations) > 0:
    
    image_info = next((image for image in dataset_view_train['images'] if image['id'] == image_id), None)
    image_dir = DB_DIR / 'train' / 'images'
    image_path = image_dir / image_info['file_name']
    image = Image.open(image_path)
    segmentations = [annotation['segmentation'] for annotation in annotations]
    mask = np.zeros((image.height, image.width), dtype=np.uint8)

    for i, segmentation in enumerate(segmentations):
        contour = np.array(segmentation).reshape((-1, 2)).astype(np.int32)
        mask = cv2.drawContours(mask, [contour], -1, (i + 1), thickness=cv2.FILLED)

    colors = [(0, 0, 0)] + [(np.random.randint(0, 256), np.random.randint(0, 256), np.random.randint(0, 256)) for _ in range(len(segmentations))]
    mask_rgb = np.zeros((image.height, image.width, 3), dtype=np.uint8)

    for i, color in enumerate(colors):
        mask_rgb[mask == i] = color

    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.title('Image')
    plt.subplot(1, 2, 2)
    plt.imshow(mask_rgb)
    plt.title('Mask')
    plt.show()
else:
    print("Image not found")

# %%
import cv2
image_id = 15
annotations = [annotation for annotation in dataset_view_test['annotations'] if annotation['image_id'] == image_id]

if len(annotations) > 0:
    
    image_info = next((image for image in dataset_view_test['images'] if image['id'] == image_id), None)
    image_dir = DB_DIR / 'test' / 'images'
    image_path = image_dir / image_info['file_name']
    image = Image.open(image_path)
    segmentations = [annotation['segmentation'] for annotation in annotations]
    category_ids = [annotation['category_id'] for annotation in annotations]
    mask = np.zeros((image.height, image.width), dtype=np.uint8)

    
    for segmentation, category_id in zip(segmentations, category_ids):
        contour = np.array(segmentation).reshape((-1, 2)).astype(np.int32)
        mask = cv2.drawContours(mask, [contour], -1, category_id, thickness=cv2.FILLED)

    category_ids = [0, 1, 2, 3, 4, 5]  # Include background
    colors = [(0, 0, 0), (0, 255, 0), (128, 50, 0), (128, 0, 128), (128, 128, 0), (255, 255, 0)]  # Example colors
    mask_rgb = np.zeros((image.height, image.width, 3), dtype=np.uint8)

    for category_id, color in zip(category_ids, colors):
        mask_rgb[mask == category_id] = color

    
    fig = plt.figure(figsize=(15, 10))
    plt.subplots_adjust(wspace=0.15)
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.title('Image')
    plt.subplot(1, 2, 2)
    plt.imshow(mask_rgb)
    plt.title('Segmentation Mask')

    plt.show()

    # Check if there are objects from all categories
    all_categories = set(category_ids)
    missing_categories = set(category_ids) ^ set(all_categories)
    if missing_categories:
        print('Missing items in the following categories:')
        for category_id in missing_categories:
            category_name = next((category['name'] for category in dataset_view_test['categories'] if category['id'] == category_id), None)
            print(category_name)
    else:
        print('Image ID:  ', image_id, '      Objects of all categories present in the image')
else:
    print("Image not found")
# Out:
# Image ID:   15       Objects of all categories present in the image

# %% [markdown]
# # MODEL SECTION

# %%
num_classes = 6
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class_weights_train = torch.tensor(class_weights_train).to(device)
class_weights_test = torch.tensor(class_weights_test).to(device)

encoder = 'resnet101'   # Encoder backbone for U-Net
e_weights = 'imagenet'  # Use pretrained ImageNet weights
train_mode = 'RAW'      # Custom training label/tag

# Pre-Trained Model from SEGMENTATION MODELS PYTORCH Library
model_Unet = smp.Unet(
    encoder_name=f'{encoder}',
    encoder_weights=f'{e_weights}',
    in_channels=3,
    classes=num_classes
)

criterion_ce = nn.CrossEntropyLoss()                                # Standard cross-entropy
criterion_w = nn.CrossEntropyLoss(weight = class_weights_train)     # Weighted cross-entropy

# Main hyperparameters
criterion_train = criterion_ce
criterion = criterion_ce
learning_rate = 0.0001
weight_decay = 0.0005
optimizer = torch.optim.Adam(model_Unet.parameters(), lr=learning_rate, weight_decay=weight_decay)
model_Unet.to(device)
model_Unet.train()
print(device)

# %%
device
OUTPUTS_DIR = ROOT / 'outputs'
OUTPUTS_DIR.mkdir(exist_ok=True)
print(f'Device: {device}')
# Out:
# Device: cuda

# %%
session = 470



def calculate_inter_union_2(predicted_masks, masks):

    """
    Calculates the intersection and union between two binary masks using bitwise operations.

    Args:
        predicted_masks (torch.Tensor): Predicted binary masks. Expected shape: (N, H, W) or (H, W).
        masks (torch.Tensor): Ground truth binary masks. Same shape as predicted_masks.

    Returns:
        tuple: A tuple (intersection, union) where both are integers representing the pixel-wise
               intersection and union between predicted and ground truth masks.
    """

    predicted_masks = predicted_masks.to(torch.int32)
    masks = masks.to(torch.int32)
    
    intersection = torch.sum(predicted_masks & masks).item()
    union = torch.sum(predicted_masks | masks).item()
    return intersection, union

def calculate_inter_union_multiclass(predicted_masks, masks, num_classes):

    """
    Calculates the total intersection and union across all classes for multi-class segmentation.

    Args:
        predicted_masks (torch.Tensor): Predicted masks with class indices. Shape: (N, H, W) or (H, W).
        masks (torch.Tensor): Ground truth masks with class indices. Same shape as predicted_masks.
        num_classes (int): Total number of classes.

    Returns:
        tuple: A tuple (intersection, union) representing the total pixel-wise intersection and union
               summed across all classes."""
    
    intersection = 0.0
    union = 0.0
    for cls in range(num_classes):
        pred_class = (predicted_masks == cls).float()
        true_class = (masks == cls).float()
        intersection += torch.sum(pred_class * true_class).item()
        union += torch.sum((pred_class + true_class) > 0).item()
    return intersection, union



session_folder = OUTPUTS_DIR / f'training_session_{session}'  
session_folder.mkdir(parents=True, exist_ok=True)

# Train loop

num_epochs = 40
checkpoint_interval = num_epochs/2  
prev_iou = None
best_iou = 0.0
saved_epoch = 0
saved_model_path = None
train_losses = []
train_iou_1 = []
train_iou_2 = []
train_iou_m = []
train_f1_scores = []
train_f2_scores = []
train_accuracies = []
train_recalls = []
test_losses = []
test_iou_1 = []
test_iou_2 = []
test_iou_m = []
test_f1_scores = []
test_f2_scores = []
test_accuracies = []
test_recalls = []


parameters_tosave = f'Learning Rate: {learning_rate}\n' \
             f'Model: Unet \n' \
             f'Epochs: {num_epochs}\n' \
             f'Encoder: {encoder} \n' \
             f'Encoder Weights: {e_weights} \n' \
             f'Weight Decay: {weight_decay}\n' \
             f'Loss Function: {criterion}\n' \
             f'Class Number: {num_classes}\n' \
             f'Dataset: {dataset_used} \n' \
             f'Training mode: {train_mode} \n' \
             f'Weighted : False \n' \


parameters_file = session_folder / 'parameters_tosave.txt'


model_Unet_prev_state = None
model_Unet_best_result = None

"""
Trains a Unet model for multi-class semantic segmentation using PyTorch.

This training loop performs supervised training on images and masks,
computing multiple performance metrics (IoU, F1, F2, accuracy, recall) 
for both training and validation/test per epoch. It also saves model 
checkpoints and stores the best model based on training IoU score.

Features:
- Supports multiple segmentation classes.
- Calculates IoU using three different methods (binary, bitwise, and multiclass).
- Logs global metrics and loss values.
- Automatically saves checkpoints and the best model.
- Includes a basic early stopping mechanism if IoU drops sharply.

Expected global parameters (must be defined before running this loop):
- model_Unet: Segmentation model (torch.nn.Module).
- dataloader_train, dataloader_test: Dataloaders for training and testing.
- criterion, criterion_train: Loss function(s).
- optimizer: Configured optimizer.
- device: Device (CPU or CUDA).
- num_epochs: Number of training epochs.
- num_classes: Number of segmentation classes.
- learning_rate, encoder, e_weights, weight_decay: Configuration parameters.
- dataset_used, train_mode: Additional information about dataset and training mode.

Outputs:
- Saves the best model (`model_Unet_best.pt`) and periodic checkpoints.
- Records metrics per epoch in global lists.
- Generates a `parameters_tosave.txt` file with training configuration.
"""


for epoch in range(num_epochs):
    # Training mode
    model_Unet.train()
    train_loss = 0.0
    intersection_1 = 0.0
    intersection2 = 0.0
    intersection_m = 0.0
    union_1 = 0.0
    union2 = 0.0
    union_m = 0.0

    tp_train = torch.zeros(1, dtype=torch.float32, device=device)
    fp_train = torch.zeros(1, dtype=torch.float32, device=device)
    fn_train = torch.zeros(1, dtype=torch.float32, device=device)
    tn_train = torch.zeros(1, dtype=torch.float32, device=device)

    for i, (images, masks) in enumerate(dataloader_train):
        optimizer.zero_grad()
        images = images.to(device)
        masks = masks.float().to(device)  
        outputs = model_Unet(images)
        loss = criterion_train(outputs, masks)
        train_loss += loss.item()
        loss.backward()
        optimizer.step()
        print('\n')

        # IoU Method 1
        predicted_masks = torch.argmax(outputs, dim=1).float()
        intersection_1 += torch.sum(predicted_masks * masks).item()
        union_1 += torch.sum((predicted_masks + masks) > 0).item()

        # IoU Method 2
        inter_2, un_2 = calculate_inter_union_2(predicted_masks, masks)
        intersection2 += inter_2
        union2 += un_2

        # IoU Multiclass
        inter_mc, un_mc = calculate_inter_union_multiclass(predicted_masks, masks, num_classes)
        intersection_m += inter_mc
        union_m += un_mc

        predicted_masks_m = torch.argmax(outputs, dim=1).unsqueeze(1).to(torch.int32)  
        masks_m = torch.argmax(masks, dim=1).unsqueeze(1).to(torch.int32)  
        tp, fp, fn, tn = smp.metrics.get_stats(predicted_masks_m, masks_m, mode='multiclass', num_classes=4)
        tp_train += tp.sum()
        fp_train += fp.sum()
        fn_train += fn.sum()
        tn_train += tn.sum()
        
        print(f'Train loss item 2: {train_loss}')
        print(f'Epoch: {epoch+1}/{num_epochs}\t Iteration: {i+1}/{len(dataloader_train)}')

    # IoU Calculations
    iou_train_1 = intersection_1 / union_1
    iou_train_2 = intersection2 / union2
    iou_train_multiclass = intersection_m / union_m

    train_iou_1.append(iou_train_1)
    train_iou_2.append(iou_train_2)
    train_iou_m.append(iou_train_multiclass)

    train_loss /= len(dataloader_train.dataset)
    train_losses.append(train_loss)
    
    # Metrics
    f1_score_train = smp.metrics.f1_score(tp_train, fp_train, fn_train, tn_train, reduction="micro")
    f2_score_train = smp.metrics.fbeta_score(tp_train, fp_train, fn_train, tn_train, beta=2, reduction="micro")
    accuracy_train = smp.metrics.accuracy(tp_train, fp_train, fn_train, tn_train, reduction="macro")
    recall_train = smp.metrics.recall(tp_train, fp_train, fn_train, tn_train, reduction="micro")
    train_f1_scores.append(f1_score_train)
    train_f2_scores.append(f2_score_train)
    train_accuracies.append(accuracy_train)
    train_recalls.append(recall_train)


    print(f'Epoch: {epoch+1}/{num_epochs}\t Training Loss: {train_loss}\t IoU: {iou_train_1}')
    print(f'IoU Method R: {iou_train_1}, intersection_1: {intersection_1}, union_1: {union_1}')
    print(f'IoU Method 2: {iou_train_2}, intersection_2: {intersection2}, union_2: {union2}')
    print(f'IoU Multiclass: {iou_train_multiclass}, intersection_m: {intersection_m}, union_m: {union_m}')
    print(f'F1 Score: {f1_score_train}, F2 Score: {f2_score_train}, Accuracy: {accuracy_train}, Recall: {recall_train}')
    print('\n\n')



    # Evaluation Mode

    tp_test = torch.zeros(1, dtype=torch.float32, device=device)
    fp_test = torch.zeros(1, dtype=torch.float32, device=device)
    fn_test = torch.zeros(1, dtype=torch.float32, device=device)
    tn_test = torch.zeros(1, dtype=torch.float32, device=device)

    model_Unet.eval()
    test_loss = 0.0
    intersection_test_1 = 0.0
    intersection_test_2 = 0.0
    intersection_test_m = 0.0
    union_test_1 = 0.0
    union_test_2 = 0.0
    union_test_m = 0.0

    with torch.no_grad():
        for images, masks in dataloader_test:
            images = images.to(device)
            masks = masks.to(device)
            outputs = model_Unet(images)

            loss = criterion(outputs, masks)

            
            predicted_masks = torch.argmax(outputs, dim=1).float()
            intersection_test_1 += torch.sum(predicted_masks * masks).item()
            union_test_1 += torch.sum((predicted_masks + masks) > 0).item()

            inter_test_2, un_test_2 = calculate_inter_union_2(predicted_masks, masks)
            intersection_test_2 += inter_test_2
            union_test_2 += un_test_2
            
            inter_test_mc, un_test_mc = calculate_inter_union_multiclass(predicted_masks, masks, num_classes)
            intersection_test_m += inter_test_mc
            union_test_m += un_test_mc

            
            test_loss += torch.sum(loss).item()
            print(f'Test loss item: {test_loss}')
            print('\n')

            predicted_masks_m = torch.argmax(outputs, dim=1).unsqueeze(1).to(torch.int32)  
            masks_m = torch.argmax(masks, dim=1).unsqueeze(1).to(torch.int32)  
            tp, fp, fn, tn = smp.metrics.get_stats(predicted_masks_m, masks_m, mode='multiclass', num_classes=4)
            tp_test += tp.sum()
            fp_test += fp.sum()
            fn_test += fn.sum()
            tn_test += tn.sum()

    # Test IoU Calculation

    iou_test_1 = intersection_test_1 / union_test_1
    iou_test_2 = intersection_test_2 / union_test_2
    iou_test_multiclass = intersection_test_m / union_test_m

    test_loss /= len(dataloader_test.dataset)

    test_iou_1.append(iou_test_1)
    test_iou_2.append(iou_test_2)
    test_iou_m.append(iou_test_multiclass)
    test_losses.append(test_loss)

    f1_score_test = smp.metrics.f1_score(tp_test, fp_test, fn_test, tn_test, reduction="micro")
    f2_score_test = smp.metrics.fbeta_score(tp_test, fp_test, fn_test, tn_test, beta=2, reduction="micro")
    accuracy_test = smp.metrics.accuracy(tp_test, fp_test, fn_test, tn_test, reduction="macro")
    recall_test = smp.metrics.recall(tp_test, fp_test, fn_test, tn_test, reduction="micro")
    
    test_f1_scores.append(f1_score_test)
    test_f2_scores.append(f2_score_test)
    test_accuracies.append(accuracy_test)
    test_recalls.append(recall_test)
  

    print(f'Test Loss: {test_loss}\t IoU: {iou_test_1}')
    print(f'Test IoU Method 2: {iou_test_2}')
    print(f'Test IoU Multiclass: {iou_test_multiclass}')
    print(f'F1 Score Test: {f1_score_test}, F2 Score Test: {f2_score_test}, Accuracy: {accuracy_test}, Recall: {recall_test}')
    print(f'Epoch: {epoch+1}/{num_epochs}\t Test Loss: {test_loss}\t IoU: {iou_test_1}', "\n\n")

    intervalo = (epoch + 1) % checkpoint_interval
    if intervalo == 0:
      print(intervalo)
      checkpoint_path = session_folder / f'model_Unet_checkpoint_epoch_{epoch+1}.pt'
      torch.save(model_Unet.state_dict(), checkpoint_path)
      print(f'Saved model checkpoint at epoch {epoch+1}: {checkpoint_path}')
      print('Parametros: ', 'learnig rate: ', learning_rate, 'Epocas: ', num_epochs)
      print('criterion: ', criterion_train, 'Optimizador: ', optimizer)
      print(f'Encoder: {encoder}')
      print(f'Sesión: {session}')

    if iou_train_1 > best_iou:
        best_iou = iou_train_1
        model_Unet_best_result = model_Unet.state_dict()
        saved_epoch = epoch 

    if model_Unet_best_result is not None:
        best_model_path = session_folder /'model_Unet_best.pt'
        torch.save(model_Unet_best_result, best_model_path)
        print(f"Model saved at epoch {saved_epoch} with best IoU: {best_iou}. Path: {best_model_path}")
  
    # Early Stopping
    if prev_iou is not None and iou_train_1 == 0: # prev_iou - iou_train > threshold:
        print(f"Sudden drop in IoU detected. Stopping training and saving model from epoch {epoch}.")
        saved_model_path = session_folder / f'model_Unet_checkpoint_epoch_{saved_epoch}.pt'
        torch.save(model_Unet_prev_state, saved_model_path)
        break
    
    if iou_train_1 != 0:
        model_Unet_prev_state = model_Unet.state_dict()
        saved_epoch = saved_epoch +1

    print('Previous IoU ', prev_iou)
    prev_iou = iou_train_1
    print('Current IoU', iou_train_1)
    print('\n\n\n\n')


# Checking parameters
for name, param in model_Unet.named_parameters():
    if 'dropout' in name:
        print(f"Dropout layer: {name}, Dropout rate: {param.item()}")


if saved_model_path is not None:
    print(f"Model saved at epoch {saved_epoch}: {saved_model_path}")

parameters_tosave += f"Best IoU: {best_iou}\n"

with open(parameters_file, 'w') as file:
    file.write(parameters_tosave)

print(f"Parameters saved at: {parameters_file}")

completed_epochs = len(train_losses)


train_f1_scores_cpu = [score.cpu().numpy() if isinstance(score, torch.Tensor) else score for score in train_f1_scores]
test_f1_scores_cpu = [score.cpu().numpy() if isinstance(score, torch.Tensor) else score for score in test_f1_scores]
train_f2_scores_cpu = [score.cpu().numpy() if isinstance(score, torch.Tensor) else score for score in train_f2_scores]
test_f2_scores_cpu = [score.cpu().numpy() if isinstance(score, torch.Tensor) else score for score in test_f2_scores]
train_accuracies_cpu = [acc.cpu().numpy() for acc in train_accuracies]
test_accuracies_cpu = [accs.cpu().numpy() for accs in test_accuracies]
train_recalls_cpu = [rec.cpu().numpy() for rec in train_recalls]
test_recalls_cpu = [rec.cpu().numpy() for rec in test_recalls]

# Losses
plt.figure(figsize=(10, 5))
plt.plot(range(1, completed_epochs+1), train_losses, label='Training Losses')
plt.plot(range(1, completed_epochs+1), test_losses, label='Test Losses')
plt.xlabel('Epoch')
plt.ylabel('Losses')
plt.title('Losses Curve')
plt.legend()
plt.grid(True)
plt.savefig(session_folder / 'loss_curve.png')
plt.show()

# Method 1
plt.figure(figsize=(10, 5))
plt.plot(range(1, completed_epochs+1), train_iou_1, label='Train IoU Method 1')
plt.plot(range(1, completed_epochs+1), test_iou_1, label='Test IoU Method 1')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.title('IoU Method 1')
plt.legend()
plt.grid(True)
plt.savefig(session_folder /'iou_curve_method_1.png')
plt.show()

# Method 2
plt.figure(figsize=(10, 5))
plt.plot(range(1, completed_epochs+1), train_iou_2, label='Train IoU Method 2')
plt.plot(range(1, completed_epochs+1), test_iou_2, label='Test IoU Method 2')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.title('IoU Method 2')
plt.legend()
plt.grid(True)
plt.savefig(session_folder / 'iou_curve_method_2.png')
plt.show()

# Multiclass Method
plt.figure(figsize=(10, 5))
plt.plot(range(1, completed_epochs+1), train_iou_m, label='Train IoU Multiclass')
plt.plot(range(1, completed_epochs+1), test_iou_m, label='Test IoU Multiclass')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.title('IoU Multiclass Method')
plt.legend()
plt.grid(True)
plt.savefig(session_folder / 'iou_curve_multiclass.png')
plt.show()

# Plotting all curves
plt.figure(figsize=(10, 5))
plt.plot(range(1, completed_epochs+1), train_iou_1, label='Train IoU Método R')
plt.plot(range(1, completed_epochs+1), test_iou_1, label='Test IoU Método R')
plt.plot(range(1, completed_epochs+1), train_iou_2, label='Train IoU Method 2')
plt.plot(range(1, completed_epochs+1), test_iou_2, label='Test IoU Method 2')
plt.plot(range(1, completed_epochs+1), train_iou_m, label='Train IoU Multiclass')
plt.plot(range(1, completed_epochs+1), test_iou_m, label='Test IoU Multiclass')
plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.title('All IoU Curves')
plt.legend()
plt.grid(True)
plt.savefig(session_folder / 'all_iou_curves.png')
plt.show()

# F1 Score 
plt.figure(figsize=(10, 5))
plt.plot(range(1, completed_epochs + 1), train_f1_scores_cpu, label='Train F1 Score')
plt.plot(range(1, completed_epochs + 1), test_f1_scores_cpu, label='Test F1 Score')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.title('F1 Score')
plt.legend()
plt.grid(True)
plt.savefig(session_folder / 'f1_score_curve.png')
plt.show()

# F2 Score 
plt.figure(figsize=(10, 5))
plt.plot(range(1, completed_epochs + 1), train_f2_scores_cpu, label='Train F2 Score')
plt.plot(range(1, completed_epochs + 1), test_f2_scores_cpu, label='Test F2 Score')
plt.xlabel('Epoch')
plt.ylabel('F2 Score')
plt.title('F2 Score')
plt.legend()
plt.grid(True)
plt.savefig(session_folder / 'f2_score_curve.png')
plt.show()

# Accuracy
plt.figure(figsize=(10, 5))
plt.plot(range(1, completed_epochs + 1), train_accuracies_cpu, label='Train Accuracy')
plt.plot(range(1, completed_epochs + 1), test_accuracies_cpu, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()
plt.grid(True)
plt.savefig(session_folder / 'accuracy_curve.png')
plt.show()

# Recall
plt.figure(figsize=(10, 5))
plt.plot(range(1, completed_epochs + 1), train_recalls_cpu, label='Train Recalls')
plt.plot(range(1, completed_epochs + 1), test_recalls_cpu, label='Test Recalls')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.title('Recall')
plt.legend()
plt.grid(True)
plt.savefig(session_folder / 'recalls_curve.png')
plt.show()
# Out:
# Count per category: {0: 306, 1: 66, 2: 141, 3: 8, 4: 11, 5: 104}
# Total number of objects: 636
#
#
# Train loss item 2: 2.1174368858337402
# Epoch: 1/40	 Iteration: 1/10
# Count per category: {0: 177, 1: 35, 2: 41, 3: 4, 4: 5, 5: 56}
# Total number of objects: 318
#
#
# Train loss item 2: 3.995706081390381
# Epoch: 1/40	 Iteration: 2/10
# Count per category: {0: 0, 1: 31, 2: 72, 3: 6, 4: 10, 5: 71}
# Total number of objects: 190
#
#
# Train loss item 2: 5.541741728782654
# Epoch: 1/40	 Iteration: 3/10
# Count per category: {0: 427, 1: 30, 2: 49, 3: 13, 4: 36, 5: 136}
# Total number of objects: 691
#
#
# Train loss item 2: 7.523303508758545
# Epoch: 1/40	 Iteration: 4/10
# Count per category: {0: 250, 1: 64, 2: 6, 3: 7, 4: 24, 5: 138}
# Total number of objects: 489
#
#
# Train loss item 2: 9.25025224685669
# Epoch: 1/40	 Iteration: 5/10
# Count per category: {0: 537, 1: 26, 2: 47, 3: 17, 4: 15, 5: 106}
# Total number of objects: 748
#
#
# Train loss item 2: 11.050512433052063
# Epoch: 1/40	 Iteration: 6/10
# Count per category: {0: 435, 1: 53, 2: 102, 3: 16, 4: 16, 5: 124}
# Total number of objects: 746
#
#
# Train loss item 2: 12.913771867752075
# Epoch: 1/40	 Iteration: 7/10
# Count per category: {0: 383, 1: 47, 2: 44, 3: 3, 4: 0, 5: 65}
# Total number of objects: 542
#
#
# Train loss item 2: 14.599028825759888
# Epoch: 1/40	 Iteration: 8/10
# Count per category: {0: 6, 1: 48, 2: 49, 3: 1, 4: 0, 5: 149}
# Total number of objects: 253
#
#
# Train loss item 2: 15.584311246871948
# Epoch: 1/40	 Iteration: 9/10
# Count per category: {0: 270, 1: 47, 2: 27, 3: 2, 4: 26, 5: 101}
# Total number of objects: 473
#
#
# Train loss item 2: 17.304656147956848
# Epoch: 1/40	 Iteration: 10/10
# Epoch: 1/40	 Training Loss: 1.7304656147956847	 IoU: 0.4498147960701076
# IoU Method R: 0.4498147960701076, intersection_1: 25032318.0, union_1: 55650277.0
# IoU Method 2: 0.05188562008753651, intersection_2: 7395756.0, union_2: 142539609.0
# IoU Multiclass: 0.10154470423668016, intersection_m: 11599421.0, union_m: 114229699.0
# F1 Score: 0.42080938816070557, F2 Score: 0.3901720941066742, Accuracy: 0.7636033892631531, Recall: 0.37211090326309204
#
#
#
# Count per category: {0: 480, 1: 36, 2: 21, 3: 27, 4: 20, 5: 87}
# Total number of objects: 671
# Test loss item: 1.7127516269683838
#
#
# Count per category: {0: 332, 1: 41, 2: 70, 3: 1, 4: 4, 5: 48}
# Total number of objects: 496
# Test loss item: 3.407764434814453
#
#
# Count per category: {0: 145, 1: 19, 2: 21, 3: 3, 4: 14, 5: 49}
# Total number of objects: 251
# Test loss item: 5.100033283233643
#
#
# Count per category: {0: 265, 1: 72, 2: 23, 3: 29, 4: 3, 5: 61}
# Total number of objects: 453
# Test loss item: 6.9561508893966675
#
#
# Test Loss: 1.7390377223491669	 IoU: 0.3789449157041564
# Test IoU Method 2: 0.06434532117799548
# Test IoU Multiclass: 0.1065075241586894
# F1 Score Test: 0.49906274676322937, F2 Score Test: 0.4836522936820984, Accuracy: 0.7996681332588196, Recall: 0.47389674186706543
# Epoch: 1/40	 Test Loss: 1.7390377223491669	 IoU: 0.3789449157041564
#
#
# Model saved at epoch 0 with best IoU: 0.4498147960701076. Path: E:\OneDrive\Tesis\outputs\training_session_470\model_Unet_best.pt
# Previous IoU  None
# Current IoU 0.4498147960701076
#
#
#
#
#
# Count per category: {0: 306, 1: 66, 2: 141, 3: 8, 4: 11, 5: 104}
# Total number of objects: 636
#
#
# Train loss item 2: 1.6906299591064453
# Epoch: 2/40	 Iteration: 1/10
# Count per category: {0: 435, 1: 53, 2: 102, 3: 16, 4: 16, 5: 124}
# Total number of objects: 746
#
#
# Train loss item 2: 3.3546923398971558
# Epoch: 2/40	 Iteration: 2/10
# Count per category: {0: 250, 1: 64, 2: 6, 3: 7, 4: 24, 5: 138}
# Total number of objects: 489
#
#
# Train loss item 2: 4.841344714164734
# Epoch: 2/40	 Iteration: 3/10
# Count per category: {0: 177, 1: 35, 2: 41, 3: 4, 4: 5, 5: 56}
# Total number of objects: 318
#
#
# Train loss item 2: 6.320324778556824
# Epoch: 2/40	 Iteration: 4/10
# Count per category: {0: 270, 1: 47, 2: 27, 3: 2, 4: 26, 5: 101}
# Total number of objects: 473
#
#
# Train loss item 2: 7.870602250099182
# Epoch: 2/40	 Iteration: 5/10
# Count per category: {0: 427, 1: 30, 2: 49, 3: 13, 4: 36, 5: 136}
# Total number of objects: 691
#
#
# Train loss item 2: 9.457812070846558
# Epoch: 2/40	 Iteration: 6/10
# Count per category: {0: 383, 1: 47, 2: 44, 3: 3, 4: 0, 5: 65}
# Total number of objects: 542
#
#
# Train loss item 2: 10.874181270599365
# Epoch: 2/40	 Iteration: 7/10
# Count per category: {0: 537, 1: 26, 2: 47, 3: 17, 4: 15, 5: 106}
# Total number of objects: 748
#
#
# Train loss item 2: 12.344882488250732
# Epoch: 2/40	 Iteration: 8/10
# Count per category: {0: 0, 1: 31, 2: 72, 3: 6, 4: 10, 5: 71}
# Total number of objects: 190
#
#
# Train loss item 2: 13.629030108451843
# Epoch: 2/40	 Iteration: 9/10
# Count per category: {0: 6, 1: 48, 2: 49, 3: 1, 4: 0, 5: 149}
# Total number of objects: 253
#
#
# Train loss item 2: 14.46887743473053
# Epoch: 2/40	 Iteration: 10/10
# Epoch: 2/40	 Training Loss: 1.446887743473053	 IoU: 0.3784508299897642
# IoU Method R: 0.3784508299897642, intersection_1: 19436494.0, union_1: 51358043.0
# IoU Method 2: 0.06849089242711325, intersection_2: 7439766.0, union_2: 108624165.0
# IoU Multiclass: 0.15605299450873283, intersection_m: 16985390.0, union_m: 108843730.0
# F1 Score: 0.6361058354377747, F2 Score: 0.6113570928573608, Accuracy: 0.8426551818847656, Recall: 0.5959007740020752
#
#
#
# Count per category: {0: 332, 1: 41, 2: 70, 3: 1, 4: 4, 5: 48}
# Total number of objects: 496
# Test loss item: 1.5537383556365967
#
#
# Count per category: {0: 265, 1: 72, 2: 23, 3: 29, 4: 3, 5: 61}
# Total number of objects: 453
# Test loss item: 3.213330030441284
#
#
# Count per category: {0: 480, 1: 36, 2: 21, 3: 27, 4: 20, 5: 87}
# Total number of objects: 671
# Test loss item: 4.749756813049316
#
#
# Count per category: {0: 145, 1: 19, 2: 21, 3: 3, 4: 14, 5: 49}
# Total number of objects: 251
# Test loss item:
#
#
#
# Count per category: {0: 480, 1: 36, 2: 21, 3: 27, 4: 20, 5: 87}
# Total number of objects: 671
# Test loss item: 1.1148231029510498
#
#
# Count per category: {0: 332, 1: 41, 2: 70, 3: 1, 4: 4, 5: 48}
# Total number of objects: 496
# Test loss item: 2.322472929954529
#
#
# Count per category: {0: 145, 1: 19, 2: 21, 3: 3, 4: 14, 5: 49}
# Total number of objects: 251
# Test loss item: 3.4797431230545044
#
#
# Count per category: {0: 265, 1: 72, 2: 23, 3: 29, 4: 3, 5: 61}
# Total number of objects: 453
# Test loss item: 4.930440306663513
#
#
# Test Loss: 1.2326100766658783	 IoU: 0.32863693282838324
# Test IoU Method 2: 0.06834173500476154
# Test IoU Multiclass: 0.16240161076382367
# F1 Score Test: 0.6895747184753418, F2 Score Test: 0.6980447173118591, Accuracy: 0.8665655255317688, Recall: 0.7038079500198364
# Epoch: 6/40	 Test Loss: 1.2326100766658783	 IoU: 0.32863693282838324
#
#
# Model saved at epoch 5 with best IoU: 0.4498147960701076. Path: E:\OneDrive\Tesis\outputs\training_session_470\model_Unet_best.pt
# Previous IoU  0.28488834542598546
# Current IoU 0.27469717009869365
#
#
#
#
#
# Count per category: {0: 427, 1: 30, 2: 49, 3: 13, 4: 36, 5: 136}
# Total number of objects: 691
#
#
# Train loss item 2: 1.0870871543884277
# Epoch: 7/40	 Iteration: 1/10
# Count per category: {0: 0, 1: 31, 2: 72, 3: 6, 4: 10, 5: 71}
# Total number of objects: 190
#
#
# Train loss item 2: 1.9451764822006226
# Epoch: 7/40	 Iteration: 2/10
# Count per category: {0: 435, 1: 53, 2: 102, 3: 16, 4: 16, 5: 124}
# Total number of objects: 746
#
#
# Train loss item 2: 3.043234705924988
# Epoch: 7/40	 Iteration: 3/10
# Count per category: {0: 270, 1: 47, 2: 27, 3: 2, 4: 26, 5: 101}
# Total number of objects: 473
#
#
# Train loss item 2: 4.076583385467529
# Epoch: 7/40	 Iteration: 4/10
# Count per category: {0: 306, 1: 66, 2: 141, 3: 8, 4: 11, 5: 104}
# Total number of objects: 636
#
#
# Train loss item 2: 5.141823053359985
# Epoch: 7/40	 Iteration: 5/10
# Count per category: {0: 250, 1: 64, 2: 6, 3: 7, 4: 24, 5: 138}
# Total number of objects: 489
#
#
# Train loss item 2: 6.100002646446228
# Epoch: 7/40	 Iteration: 6/10
# Count per category: {0: 6, 1: 48, 2: 49, 3: 1, 4: 0, 5: 149}
# Total number of objects: 253
#
#
# Train loss item 2: 6.647657155990601
# Epoch: 7/40	 Iteration: 7/10
# Count per category: {0: 177, 1: 35, 2: 41, 3: 4, 4: 5, 5: 56}
# Total number of objects: 318
#
#
# Train loss item 2: 7.5612905621528625
# Epoch: 7/40	 Iteration: 8/10
# Count per category: {0: 537, 1: 26, 2: 47, 3: 17, 4: 15, 5: 106}
# Total number of objects: 748
#
#
# Train loss item 2: 8.543118298053741
# Epoch: 7/40	 Iteration: 9/10
# Count per category: {0: 383, 1: 47, 2: 44, 3: 3, 4: 0, 5: 65}
# Total number of objects: 542
#
#
# Train loss item 2: 9.46586686372757
# Epoch: 7/40	 Iteration: 10/10
# Epoch: 7/40	 Training Loss: 0.946586686372757	 IoU: 0.2662573835024123
# IoU Method R: 0.2662573835024123, intersection_1: 12711185.0, union_1: 47740216.0
# IoU Method 2: 0.1002498627764935, intersection_2: 7251163.0, union_2: 72330902.0
# IoU Multiclass: 0.20818161384753459, intersection_m: 21681599.0, union_m: 104147521.0
# F1 Score: 0.8123000860214233, F2 Score: 0.8147475719451904, Accuracy: 0.9129282832145691, Recall: 0.816387414932251
#
#
#
# Count per category: {0: 332, 1: 41, 2: 70, 3: 1, 4: 4, 5: 48}
# Total number of objects: 496
# Test loss item: 1.1807236671447754
#
#
# Count per category: {0: 145, 1: 19, 2: 21, 3: 3, 4: 14, 5: 49}
# Total number of objects: 251
# Test loss item: 2.3137238025665283
#
#
# Count per category: {0: 265, 1: 72, 2: 23, 3: 29, 4: 3, 5: 61}
# Total number of objects: 453
# Test loss item: 3.7253241539001465
#
#
# Count per category: {0: 480, 1: 36, 2: 21, 3: 27, 4: 20, 5: 87}
# Total number of objects: 671
# Test loss item: 4.791898488998413
#
#
# Test Loss: 1.1979746222496033	 IoU: 0.31889511909833523
# Test IoU Method 2: 0.06674902484390523
# Test IoU Multiclass: 0.1648633900446392
# F1 Score Test: 0.6905778050422668, F2 Score Test: 0.7029206156730652, Accuracy: 0.8657577633857727, Recall: 0.7113972306251526
# Epoch: 7/40	 Test Loss: 1.1979746222496033	 IoU: 0.31889511909833523
#
#
# Model saved at epoch 6 with best IoU: 0.4498147960701076. Path: E:\OneDrive\Tesis\outputs\training_session_470\model_Unet_best.pt
# Previous IoU  0.27469717009869365
# Current IoU 0.2662573835024123
#
#
#
#
#
# Count per category: {0: 306, 1: 66, 2: 141, 3: 8, 4: 11, 5: 104}
# Total number of objects: 636
#
#
# Train loss item 2: 1.0296496152877808
# Epoch: 8/40	 Iteration: 1/10
# Count per category: {0: 537, 1: 26, 2: 47, 3: 17, 4: 15, 5: 106}
# Total number of objects: 748
#
#
# Train loss item 2: 1.9805402755737305
# Epoch: 8/40	 Iteration: 2/10
# Count per category: {0: 427, 1: 30, 2: 49, 3: 13, 4: 36, 5: 136}
# Total number of objects: 691
#
#
# Train loss item 2: 3.009389042854309
# Epoch: 8/40	 Iteration: 3/10
# Count per category: {0: 250, 1: 64, 2: 6, 3: 7, 4: 24, 5: 138}
# Total number of objects: 489
#
#
# Train loss item 2: 3.9189141988754272
# Epoch: 8/40	 Iteration: 4/10
# Count per category: {0: 435, 1: 53, 2: 102, 3: 16, 4: 16, 5: 124}
# Total number of objects: 746
#
#
# Train loss item 2: 4.946666598320007
# Epoch: 8/40	 Iteration: 5/10
# Count per category: {0: 0, 1: 31, 2: 72, 3: 6, 4: 10, 5: 71}
# Total number of objects: 190
#
#
# Train loss item 2: 5.7600701451301575
# Epoch: 8/40	 Iteration: 6/10
# Count per category: {0: 270, 1: 47, 2: 27, 3: 2, 4: 26, 5: 101}
# Total number of objects: 473
#
#
# Train loss item 2: 6.731240451335907
# Epoch: 8/40	 Iteration: 7/10
# Count per category: {0: 383, 1: 47, 2: 44, 3: 3, 4: 0, 5: 65}
# Total number of objects: 542
#
#
# Train loss item 2: 7.603768765926361
# Epoch: 8/40	 Iteration: 8/10
# Count per category: {0: 6, 1: 48, 2: 49, 3: 1, 4: 0, 5: 149}
# Total number of objects: 253
#
#
# Train loss item 2: 8.119589865207672
# Epoch: 8/40	 Iteration: 9/10
# Count per category: {0: 177, 1: 35, 2: 41, 3: 4, 4: 5, 5: 56}
# Total number of objects: 318
#
#
# Train loss item 2: 8.974182546138763
# Epoch: 8/40	 Iteration: 10/10
# Epoch: 8/40	 Training Loss: 0.8974182546138764	 IoU: 0.2690953019965097
# IoU Method R: 0.2690953019965097, intersection_1: 12813807.0, union_1: 47618100.0
# IoU Method 2: 0.09964360226943456, intersection_2: 7224319.0, union_2: 72501584.0
# IoU Multiclass: 0.20900811216199372, intersection_m: 21752796.0, union_m: 104076324.0
# F1 Score: 0.8216667175292969, F2 Score: 0.8239367604255676, Accuracy: 0.91730797290802, Recall: 0.8254570364952087
#
#
#
# Count per category: {0: 145, 1: 19, 2: 21, 3: 3, 4: 14, 5: 49}
# Total number of objects: 251
# Test loss item: 1.0609160661697388
#
#
# Count per category: {0: 265, 1: 72, 2: 23, 3: 29, 4: 3, 5: 61}
# Total number of objects: 453
# Test loss item: 2.357801079750061
#
#
# Count per category: {0: 480, 1: 36, 2: 21, 3: 27, 4: 20, 5: 87}
# Total number of objects: 671
# Test loss item: 3.373460531234741
#
#
# Count per category: {0: 332, 1: 41, 2: 70, 3: 1, 4: 4, 5: 48}
# Total number of objects: 496
# Test loss item: 4.451195120811462
#
#
# Test Loss: 1.1127987802028656	 IoU: 0.3269419813648856
# Test IoU Method 2: 0.07735222905707735
# Test IoU Multiclass: 0.18254182767003704
# F1 Score Test: 0.7357261180877686, F2 Score Test: 0.7404978275299072, Accuracy: 0.8874924182891846, Recall: 0.74371337890625
# Epoch: 8/40	 Test Loss: 1.1127987802028656	 IoU: 0.3269419813648856
#
#
# Model saved at epoch 7 with best IoU: 0.4498147960701076. Path: E:\OneDrive\Tesis\outputs\training_session_470\model_Unet_best.pt
# Previous IoU  0.2662573835024123
# Current IoU 0.2690953019965097
#
#
#
#
#
# Count per category: {0: 0, 1: 31, 2: 72, 3: 6, 4: 10, 5: 71}
# Total number of objects: 190
#
#
# Train loss item 2: 0.7812203764915466
# Epoch: 9/40	 Iteration: 1/10
# Count per category: {0: 383, 1: 47, 2: 44, 3: 3, 4: 0, 5: 65}
# Total number of objects: 542
#
#
# Train loss item 2: 1.6205604672431946
# Epoch: 9/40	 Iteration: 2/10
# Count per category: {0: 250, 1: 64, 2: 6, 3: 7, 4: 24, 5: 138}
# Total number of objects: 489
#
#
# Train loss item 2: 2.4808669686317444
# Epoch: 9/40	 Iteration: 3/10
# Count per category: {0: 270, 1: 47, 2: 27, 3: 2, 4: 26, 5: 101}
# Total number of objects: 473
#
#
# Train loss item 2: 3.4028493762016296
# Epoch: 9/40	 Iteration: 4/10
# Count per category: {0: 6, 1: 48, 2: 49, 3: 1, 4: 0, 5: 149}
# Total number of objects: 253
#
#
# Train loss item 2: 3.888171464204788
# Epoch: 9/40	 Iteration: 5/10
# Count per category: {0: 306, 1: 66, 2: 141, 3: 8, 4: 11, 5: 104}
# Total number of objects: 636
#
#
# Train loss item 2: 4.860158532857895
# Epoch: 9/40	 Iteration: 6/10
# Count per category: {0: 427, 1: 30, 2: 49, 3: 13, 4: 36, 5: 136}
# Total number of objects: 691
#
#
# Train loss item 2: 5.835795372724533
# Epoch: 9/40	 Iteration: 7/10
# Count per category: {0: 537, 1: 26, 2: 47, 3: 17, 4: 15, 5: 106}
# Total number of objects: 748
#
#
# Train loss item 2: 6.7330752313137054
# Epoch: 9/40	 Iteration: 8/10
# Count per category: {0: 435, 1: 53, 2: 102, 3: 16, 4: 16, 5: 124}
# Total number of objects: 746
#
#
# Train loss item 2: 7.707964509725571
# Epoch: 9/40	 Iteration: 9/10
# Count per category: {0: 177, 1: 35, 2: 41, 3: 4, 4: 5, 5: 56}
# Total number of objects: 318
#
#
# Train loss item 2: 8.523474007844925
# Epoch: 9/40	 Iteration: 10/10
# Epoch: 9/40	 Training Loss: 0.8523474007844924	 IoU: 0.27109607164267746
# IoU Method R: 0.27109607164267746, intersection_1: 12912288.0, union_1: 47629934.0
# IoU Method 2: 0.09943206445030181, intersection_2: 7264144.0, union_2: 73056353.0
# IoU Multiclass: 0.2088064940501721, intersection_m: 21735437.0, union_m: 104093683.0
# F1 Score: 0.8317787647247314, F2 Score: 0.833088755607605, Accuracy: 0.9221509695053101, Recall: 0.8339644074440002
#
#
#
# Count per category: {0: 145, 1: 19, 2: 21, 3: 3, 4: 14, 5: 49}
# Total number of objects: 251
# Test loss item: 1.0525352954864502
#
#
# Count per category: {0: 332, 1: 41, 2: 70, 3: 1, 4: 4, 5: 48}
# Total number of objects: 496
# Test loss item: 2.1316661834716797
#
#
# Count per category: {0: 265, 1: 72, 2: 23, 3: 29, 4: 3, 5: 61}
# Total number of objects: 453
# Test loss item: 3.4438774585723877
#
#
# Count per category: {0: 480, 1: 36, 2: 21, 3: 27, 4: 20, 5: 87}
# Total number of objects: 671
# Test loss item: 4.442000687122345
#
#
# Test Loss: 1.1105001717805862	 IoU: 0.3397585625241094
# Test IoU Method 2: 0.06695934766197054
# Test IoU Multiclass: 0.17207221964021333
# F1 Score Test: 0.7176312208175659, F2 Score Test: 0.7224782705307007, Accuracy: 0.8797352910041809, Recall: 0.7257461547851562
# Epoch: 9/40	 Test Loss: 1.1105001717805862	 IoU: 0.3397585625241094
#
#
# Model saved at epoch 8 with best IoU: 0.4498147960701076. Path: E:\OneDrive\Tesis\outputs\training_session_470\model_Unet_best.pt
# Previous IoU  0.2690953019965097
# Current IoU 0.27109607164267746
#
#
#
#
#
# Count per category: {0: 270, 1: 47, 2: 27, 3: 2, 4: 26, 5: 101}
# Total number of objects: 473
#
#
# Train loss item 2: 0.8901408314704895
# Epoch: 10/40	 Iteration: 1/10
# Count per category: {0: 6, 1: 48, 2: 49, 3: 1, 4: 0, 5: 149}
# Total number of objects: 253
#
#
# Train loss item 2: 1.3516033589839935
# Epoch: 10/40	 Iteration: 2/10
# Count per category: {0: 0, 1: 31, 2: 72, 3: 6, 4: 10, 5: 71}
# Total number of objects: 190
#
#
# Train loss item 2: 2.1018454134464264
# Epoch: 10/40	 Iteration: 3/10
# Count per category: {0: 427, 1: 30, 2: 49, 3: 13, 4: 36, 5: 136}
# Total number of objects: 691
#
#
# Train loss item 2: 3.0421347320079803
# Epoch: 10/40	 Iteration: 4/10
# Count per category: {0: 250, 1: 64, 2: 6, 3: 7, 4: 24, 5: 138}
# Total number of objects: 489
#
#
# Train loss item 2: 3.8482929170131683
# Epoch: 10/40	 Iteration: 5/10
# Count per category: {0: 306, 1: 66, 2: 141, 3: 8, 4: 11, 5: 104}
# Total number of objects: 636
#
#
# Train loss item 2: 4.782017260789871
# Epoch: 10/40	 Iteration: 6/10
# Count per category: {0: 435, 1: 53, 2: 102, 3: 16, 4: 16, 5: 124}
# Total number of objects: 746
#
#
# Train loss item 2: 5.7296721041202545
# Epoch: 10/40	 Iteration: 7/10
# Count per category: {0: 383, 1: 47, 2: 44, 3: 3, 4: 0, 5: 65}
# Total number of objects: 542
#
#
# Train loss item 2: 6.521334856748581
# Epoch: 10/40	 Iteration: 8/10
# Count per category: {0: 537, 1: 26, 2: 47, 3: 17, 4: 15, 5: 106}
# Total number of objects: 748
#
#
# Train loss item 2:
10
# Count per category: {0: 177, 1: 35, 2: 41, 3: 4, 4: 5, 5: 56}
# Total number of objects: 318
#
#
# Train loss item 2: 1.4994738698005676
# Epoch: 14/40	 Iteration: 2/10
# Count per category: {0: 306, 1: 66, 2: 141, 3: 8, 4: 11, 5: 104}
# Total number of objects: 636
#
#
# Train loss item 2: 2.3387069702148438
# Epoch: 14/40	 Iteration: 3/10
# Count per category: {0: 6, 1: 48, 2: 49, 3: 1, 4: 0, 5: 149}
# Total number of objects: 253
#
#
# Train loss item 2: 2.727863073348999
# Epoch: 14/40	 Iteration: 4/10
# Count per category: {0: 537, 1: 26, 2: 47, 3: 17, 4: 15, 5: 106}
# Total number of objects: 748
#
#
# Train loss item 2: 3.4862220883369446
# Epoch: 14/40	 Iteration: 5/10
# Count per category: {0: 383, 1: 47, 2: 44, 3: 3, 4: 0, 5: 65}
# Total number of objects: 542
#
#
# Train loss item 2: 4.191318571567535
# Epoch: 14/40	 Iteration: 6/10
# Count per category: {0: 435, 1: 53, 2: 102, 3: 16, 4: 16, 5: 124}
# Total number of objects: 746
#
#
# Train loss item 2: 5.043136775493622
# Epoch: 14/40	 Iteration: 7/10
# Count per category: {0: 270, 1: 47, 2: 27, 3: 2, 4: 26, 5: 101}
# Total number of objects: 473
#
#
# Train loss item 2: 5.828515827655792
# Epoch: 14/40	 Iteration: 8/10
# Count per category: {0: 0, 1: 31, 2: 72, 3: 6, 4: 10, 5: 71}
# Total number of objects: 190
#
#
# Train loss item 2: 6.531444251537323
# Epoch: 14/40	 Iteration: 9/10
# Count per category: {0: 250, 1: 64, 2: 6, 3: 7, 4: 24, 5: 138}
# Total number of objects: 489
#
#
# Train loss item 2: 7.217313826084137
# Epoch: 14/40	 Iteration: 10/10
# Epoch: 14/40	 Training Loss: 0.7217313826084137	 IoU: 0.28228490425338076
# IoU Method R: 0.28228490425338076, intersection_1: 13300216.0, union_1: 47116285.0
# IoU Method 2: 0.0967068779889358, intersection_2: 7208542.0, union_2: 74540117.0
# IoU Multiclass: 0.2126238348832502, intersection_m: 22063124.0, union_m: 103765996.0
# F1 Score: 0.8486489653587341, F2 Score: 0.8475244045257568, Accuracy: 0.9302957653999329, Recall: 0.8467763662338257
#
#
#
# Count per category: {0: 332, 1: 41, 2: 70, 3: 1, 4: 4, 5: 48}
# Total number of objects: 496
# Test loss item: 0.9651034474372864
#
#
# Count per category: {0: 145, 1: 19, 2: 21, 3: 3, 4: 14, 5: 49}
# Total number of objects: 251
# Test loss item: 1.9277273416519165
#
#
# Count per category: {0: 480, 1: 36, 2: 21, 3: 27, 4: 20, 5: 87}
# Total number of objects: 671
# Test loss item: 2.825238525867462
#
#
# Count per category: {0: 265, 1: 72, 2: 23, 3: 29, 4: 3, 5: 61}
# Total number of objects: 453
# Test loss item: 4.029449045658112
#
#
# Test Loss: 1.007362261414528	 IoU: 0.35453126947295016
# Test IoU Method 2: 0.06901171882402833
# Test IoU Multiclass: 0.19045598245685325
# F1 Score Test: 0.7458326816558838, F2 Score Test: 0.74335116147995, Accuracy: 0.893549382686615, Recall: 0.7417059540748596
# Epoch: 14/40	 Test Loss: 1.007362261414528	 IoU: 0.35453126947295016
#
#
# Model saved at epoch 13 with best IoU: 0.4498147960701076. Path: E:\OneDrive\Tesis\outputs\training_session_470\model_Unet_best.pt
# Previous IoU  0.28334470816488116
# Current IoU 0.28228490425338076
#
#
#
#
#
# Count per category: {0: 270, 1: 47, 2: 27, 3: 2, 4: 26, 5: 101}
# Total number of objects: 473
#
#
# Train loss item 2: 0.7500370740890503
# Epoch: 15/40	 Iteration: 1/10
# Count per category: {0: 6, 1: 48, 2: 49, 3: 1, 4: 0, 5: 149}
# Total number of objects: 253
#
#
# Train loss item 2: 1.1446586549282074
# Epoch: 15/40	 Iteration: 2/10
# Count per category: {0: 383, 1: 47, 2: 44, 3: 3, 4: 0, 5: 65}
# Total number of objects: 542
#
#
# Train loss item 2: 1.8305966556072235
# Epoch: 15/40	 Iteration: 3/10
# Count per category: {0: 250, 1: 64, 2: 6, 3: 7, 4: 24, 5: 138}
# Total number of objects: 489
#
#
# Train loss item 2: 2.476695030927658
# Epoch: 15/40	 Iteration: 4/10
# Count per category: {0: 306, 1: 66, 2: 141, 3: 8, 4: 11, 5: 104}
# Total number of objects: 636
#
#
# Train loss item 2: 3.293993800878525
# Epoch: 15/40	 Iteration: 5/10
# Count per category: {0: 427, 1: 30, 2: 49, 3: 13, 4: 36, 5: 136}
# Total number of objects: 691
#
#
# Train loss item 2: 4.141979426145554
# Epoch: 15/40	 Iteration: 6/10
# Count per category: {0: 0, 1: 31, 2: 72, 3: 6, 4: 10, 5: 71}
# Total number of objects: 190
#
#
# Train loss item 2: 4.78825506567955
# Epoch: 15/40	 Iteration: 7/10
# Count per category: {0: 177, 1: 35, 2: 41, 3: 4, 4: 5, 5: 56}
# Total number of objects: 318
#
#
# Train loss item 2: 5.460012048482895
# Epoch: 15/40	 Iteration: 8/10
# Count per category: {0: 537, 1: 26, 2: 47, 3: 17, 4: 15, 5: 106}
# Total number of objects: 748
#
#
# Train loss item 2: 6.2018652856349945
# Epoch: 15/40	 Iteration: 9/10
# Count per category: {0: 435, 1: 53, 2: 102, 3: 16, 4: 16, 5: 124}
# Total number of objects: 746
#
#
# Train loss item 2: 7.036099940538406
# Epoch: 15/40	 Iteration: 10/10
# Epoch: 15/40	 Training Loss: 0.7036099940538406	 IoU: 0.284735362411555
# IoU Method R: 0.284735362411555, intersection_1: 13381990.0, union_1: 46997991.0
# IoU Method 2: 0.09594772510126401, intersection_2: 7201172.0, union_2: 75053077.0
# IoU Multiclass: 0.21342141222661146, intersection_m: 22131329.0, union_m: 103697791.0
# F1 Score: 0.85810786485672, F2 Score: 0.8558439612388611, Accuracy: 0.9347950220108032, Recall: 0.8543412089347839
#
#
#
# Count per category: {0: 332, 1: 41, 2: 70, 3: 1, 4: 4, 5: 48}
# Total number of objects: 496
# Test loss item: 0.976427435874939
#
#
# Count per category: {0: 480, 1: 36, 2: 21, 3: 27, 4: 20, 5: 87}
# Total number of objects: 671
# Test loss item: 1.894931435585022
#
#
# Count per category: {0: 265, 1: 72, 2: 23, 3: 29, 4: 3, 5: 61}
# Total number of objects: 453
# Test loss item: 3.1138057708740234
#
#
# Count per category: {0: 145, 1: 19, 2: 21, 3: 3, 4: 14, 5: 49}
# Total number of objects: 251
# Test loss item: 4.055152535438538
#
#
# Test Loss: 1.0137881338596344	 IoU: 0.3731002158885753
# Test IoU Method 2: 0.06146053728464793
# Test IoU Multiclass: 0.17256888104085297
# F1 Score Test: 0.7245683670043945, F2 Score Test: 0.7200697660446167, Accuracy: 0.8851969838142395, Recall: 0.7171016335487366
# Epoch: 15/40	 Test Loss: 1.0137881338596344	 IoU: 0.3731002158885753
#
#
# Model saved at epoch 14 with best IoU: 0.4498147960701076. Path: E:\OneDrive\Tesis\outputs\training_session_470\model_Unet_best.pt
# Previous IoU  0
10
# Count per category: {0: 383, 1: 47, 2: 44, 3: 3, 4: 0, 5: 65}
# Total number of objects: 542
#
#
# Train loss item 2: 4.289140343666077
# Epoch: 39/40	 Iteration: 10/10
# Epoch: 39/40	 Training Loss: 0.4289140343666077	 IoU: 0.2907910227750991
# IoU Method R: 0.2907910227750991, intersection_1: 13600853.0, union_1: 46771915.0
# IoU Method 2: 0.09260765179069728, intersection_2: 7076793.0, union_2: 76416936.0
# IoU Multiclass: 0.214095009296484, intersection_m: 22188862.0, union_m: 103640258.0
# F1 Score: 0.8981279134750366, F2 Score: 0.8937054872512817, Accuracy: 0.9533640742301941, Recall: 0.8907813429832458
#
#
#
# Count per category: {0: 332, 1: 41, 2: 70, 3: 1, 4: 4, 5: 48}
# Total number of objects: 496
# Test loss item: 0.8690706491470337
#
#
# Count per category: {0: 265, 1: 72, 2: 23, 3: 29, 4: 3, 5: 61}
# Total number of objects: 453
# Test loss item: 2.0502195358276367
#
#
# Count per category: {0: 480, 1: 36, 2: 21, 3: 27, 4: 20, 5: 87}
# Total number of objects: 671
# Test loss item: 2.8348491191864014
#
#
# Count per category: {0: 145, 1: 19, 2: 21, 3: 3, 4: 14, 5: 49}
# Total number of objects: 251
# Test loss item: 3.6631797552108765
#
#
# Test Loss: 0.9157949388027191	 IoU: 0.3497280194436176
# Test IoU Method 2: 0.06862414535139069
# Test IoU Multiclass: 0.19203282996759094
# F1 Score Test: 0.7666375041007996, F2 Score Test: 0.7656534314155579, Accuracy: 0.9019291400909424, Recall: 0.7649989128112793
# Epoch: 39/40	 Test Loss: 0.9157949388027191	 IoU: 0.3497280194436176
#
#
# Model saved at epoch 38 with best IoU: 0.4498147960701076. Path: E:\OneDrive\Tesis\outputs\training_session_470\model_Unet_best.pt
# Previous IoU  0.29052171666360527
# Current IoU 0.2907910227750991
#
#
#
#
#
# Count per category: {0: 270, 1: 47, 2: 27, 3: 2, 4: 26, 5: 101}
# Total number of objects: 473
#
#
# Train loss item 2: 0.46844324469566345
# Epoch: 40/40	 Iteration: 1/10
# Count per category: {0: 306, 1: 66, 2: 141, 3: 8, 4: 11, 5: 104}
# Total number of objects: 636
#
#
# Train loss item 2: 0.9786952435970306
# Epoch: 40/40	 Iteration: 2/10
# Count per category: {0: 177, 1: 35, 2: 41, 3: 4, 4: 5, 5: 56}
# Total number of objects: 318
#
#
# Train loss item 2: 1.325134038925171
# Epoch: 40/40	 Iteration: 3/10
# Count per category: {0: 435, 1: 53, 2: 102, 3: 16, 4: 16, 5: 124}
# Total number of objects: 746
#
#
# Train loss item 2: 1.8731712102890015
# Epoch: 40/40	 Iteration: 4/10
# Count per category: {0: 427, 1: 30, 2: 49, 3: 13, 4: 36, 5: 136}
# Total number of objects: 691
#
#
# Train loss item 2: 2.4285205602645874
# Epoch: 40/40	 Iteration: 5/10
# Count per category: {0: 6, 1: 48, 2: 49, 3: 1, 4: 0, 5: 149}
# Total number of objects: 253
#
#
# Train loss item 2: 2.609678089618683
# Epoch: 40/40	 Iteration: 6/10
# Count per category: {0: 0, 1: 31, 2: 72, 3: 6, 4: 10, 5: 71}
# Total number of objects: 190
#
#
# Train loss item 2: 2.9741560518741608
# Epoch: 40/40	 Iteration: 7/10
# Count per category: {0: 537, 1: 26, 2: 47, 3: 17, 4: 15, 5: 106}
# Total number of objects: 748
#
#
# Train loss item 2: 3.439981907606125
# Epoch: 40/40	 Iteration: 8/10
# Count per category: {0: 383, 1: 47, 2: 44, 3: 3, 4: 0, 5: 65}
# Total number of objects: 542
#
#
# Train loss item 2: 3.834124743938446
# Epoch: 40/40	 Iteration: 9/10
# Count per category: {0: 250, 1: 64, 2: 6, 3: 7, 4: 24, 5: 138}
# Total number of objects: 489
#
#
# Train loss item 2: 4.174232542514801
# Epoch: 40/40	 Iteration: 10/10
# Epoch: 40/40	 Training Loss: 0.4174232542514801	 IoU: 0.29102650692575716
# IoU Method R: 0.29102650692575716, intersection_1: 13539111.0, union_1: 46521917.0
# IoU Method 2: 0.09052280409055373, intersection_2: 6912439.0, union_2: 76361300.0
# IoU Multiclass: 0.2151189238245185, intersection_m: 22276194.0, union_m: 103552926.0
# F1 Score: 0.9037423729896545, F2 Score: 0.8991755247116089, Accuracy: 0.955943763256073, Recall: 0.8961564898490906
#
#
#
# Count per category: {0: 145, 1: 19, 2: 21, 3: 3, 4: 14, 5: 49}
# Total number of objects: 251
# Test loss item: 0.8250566720962524
#
#
# Count per category: {0: 332, 1: 41, 2: 70, 3: 1, 4: 4, 5: 48}
# Total number of objects: 496
# Test loss item: 1.7099383473396301
#
#
# Count per category: {0: 480, 1: 36, 2: 21, 3: 27, 4: 20, 5: 87}
# Total number of objects: 671
# Test loss item: 2.498104751110077
#
#
# Count per category: {0: 265, 1: 72, 2: 23, 3: 29, 4: 3, 5: 61}
# Total number of objects: 453
# Test loss item: 3.702328145503998
#
#
# Test Loss: 0.9255820363759995	 IoU: 0.3427959636542572
# Test IoU Method 2: 0.07015300230392192
# Test IoU Multiclass: 0.18892598829632462
# F1 Score Test: 0.7624040246009827, F2 Score Test: 0.7635304927825928, Accuracy: 0.8996894955635071, Recall: 0.7642833590507507
# Epoch: 40/40	 Test Loss: 0.9255820363759995	 IoU: 0.3427959636542572
#
#
# 0.0
# Saved model checkpoint at epoch 40: E:\OneDrive\Tesis\outputs\training_session_470\model_Unet_checkpoint_epoch_40.pt
# Parametros:  learnig rate:  0.0001 Epocas:  40
# criterion:  CrossEntropyLoss() Optimizador:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.0005
# )
# Encoder: resnet101
# Sesión: 470
# Model saved at epoch 39 with best IoU: 0.4498147960701076. Path: E:\OneDrive\Tesis\outputs\training_session_470\model_Unet_best.pt
# Previous IoU  0.2907910227750991
# Current IoU 0.29102650692575716
#
#
#
#
#
# Parameters saved at: E:\OneDrive\Tesis\outputs\training_session_470\parameters_tosave.txt

# %% [markdown]
# 32: [0.01629927, 0.133656, 0.44484855,  0.94456, 0.474887, 0.08930389]

# %% [markdown]
# Sesion 9

# %% [markdown]
# # INFERENCE

# %%
"""
Script for semantic segmentation inference using a pretrained Unet model from the
Segmentation Models Pytorch (SMP) library. It performs the following tasks:

1. Loads a trained Unet model with a ResNet101 encoder.
2. Preprocesses an input image and performs segmentation.
3. Maps the predicted mask to class names and colors.
4. Calculates the pixel-wise class distribution.
5. Displays and saves a comparison between the original image and the segmented output.

Assumptions:
- The model is trained for 6 classes (including background).
- Image is resized to 1024x1024 for inference.
- Class labels and colors are hardcoded and must match the training configuration.
"""

from pathlib import Path
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
import segmentation_models_pytorch as smp
from matplotlib.patches import Patch
from matplotlib.colors import ListedColormap
import segmentation_models_pytorch as smp

ROOT = Path().resolve()
OUTPUTS_DIR = ROOT / 'outputs'
OUTPUTS_DIR.mkdir(exist_ok=True)

INFERENCE_IMAGES_DIR = ROOT / 'inference_inputs'
INFERENCE_IMAGES_DIR.mkdir(exist_ok=True)

num_classes = 6
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

encoder = 'resnet101'
e_weights = 'imagenet'   
train_mode = 'RAW'
model_u = 'Unet'  
session = 46

session_folder = OUTPUTS_DIR / f'training_session_{session}'
model_path = session_folder / f'model_Unet_{session}_checkpoint_epoch_40.pt'


model_Unet = smp.Unet(
    encoder_name=f"{encoder}",
    encoder_weights=f"{e_weights}",
    in_channels=3,
    classes=num_classes,
    
)

# Loading weights

model_Unet.load_state_dict(torch.load(model_path, map_location=device))
model_Unet.eval()

# Image loading and preprocessing
image_path =  INFERENCE_IMAGES_DIR / '20220921_162649249_iOS.jpg'

image = Image.open(image_path).convert('RGB')
image = image.resize((1024, 1024))
image_original = image
preprocess = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
input_image = preprocess(image).unsqueeze(0)


# Inference
with torch.no_grad():
    output = model_Unet(input_image)
print(output)
predicted_masks = torch.argmax(output, dim=1)
input_image_np = input_image.squeeze(0).permute(1, 2, 0).numpy()
predicted_masks_np = predicted_masks.squeeze(0).numpy()

# Class and category mapping
class_names_f = ["Non-plant area", "Healthy Plants", "Early Botrytis (Stage 1)", "Advanced Botrytis (Stage 2)", "Non-reverse Botrytis (Stage 3)", "Nutritional Deficiencies"]
class_colors = ['black','green','brown', 'purple', 'orange', 'yellow']

# Checking and mapping of unique values
unique_values = np.unique(predicted_masks_np)
predicted_categories = [class_names_f[value] for value in unique_values]

# Pixel count
class_pixels = {class_name: np.sum(predicted_masks_np == class_id) for class_id, class_name in enumerate(class_names_f)}
total_pixels = np.sum(list(class_pixels.values()))

# Percentages present in the inference
class_percentages = {class_name: pixels / total_pixels * 100 for class_name, pixels in class_pixels.items()}
largest_class = max(class_percentages, key=class_percentages.get)
if largest_class == 'background':
    del class_percentages[largest_class]
    largest_class = max(class_percentages, key=class_percentages.get)

# Most detected disease
print("Class with the largest presence:", largest_class)

# Class percentages
for class_name, percentage in class_percentages.items():
    print(f"{class_name}: {percentage:.2f}%")


# Configuration of graphs
cmap = plt.get_cmap('tab10', len(class_names_f))
legend_elements = [plt.Line2D([0], [0], marker='o', color='w', label=class_name, markerfacecolor=color, markersize=10) for class_name, color in zip(class_names_f, class_colors)]
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].imshow(image_original)
axes[0].set_title("Original images")
axes[0].axis('off')
axes[1].imshow(predicted_masks_np, cmap=ListedColormap(class_colors))
axes[1].set_title('Segmented Diseases')
axes[1].axis('equal')
axes[1].axis('off')

# Legends
axes[1].legend(handles=legend_elements, loc='upper left')
plt.tight_layout()

image_name = image_path.stem

# Save image prediction comparison
comparison_image_path = session_folder / f'{image_name}_comparison_image.png'
plt.savefig(comparison_image_path)
plt.show()
# Out:
# tensor([[[[ 0.6213,  0.7257,  0.8878,  ...,  0.9487,  0.7619,  0.2426],
#           [ 1.2456,  2.1136,  2.3597,  ...,  1.9781,  1.8909,  1.1292],
#           [ 1.6433,  2.8271,  2.9617,  ...,  2.5429,  2.3749,  1.2181],
#           ...,
#           [ 0.0976, -0.6272, -1.6122,  ...,  0.6529,  0.4989,  0.0535],
#           [ 0.4391, -0.2432, -0.8028,  ...,  0.6717,  0.3167, -0.0389],
#           [ 0.7654,  0.1842, -0.1396,  ...,  0.6493,  0.5689,  0.1175]],
#
#          [[ 0.5213,  0.9608,  0.6023,  ...,  0.4474,  0.6737,  0.3258],
#           [ 0.8726,  0.8369,  0.8264,  ...,  0.3494,  0.2893,  0.4113],
#           [ 0.6277,  0.7042,  0.6545,  ...,  0.7143,  0.6441,  0.4364],
#           ...,
#           [ 1.5268,  2.4332,  2.1999,  ...,  0.4765,  0.5047,  0.1069],
#           [ 1.2944,  1.8153,  1.3888,  ...,  0.6792,  0.7270,  0.2689],
#           [ 0.2740,  0.8907,  0.8103,  ...,  0.7505,  0.6833,  0.5781]],
#
#          [[-0.9259, -1.2756, -1.5639,  ..., -1.2989, -1.0998, -0.4825],
#           [-1.4266, -1.8522, -2.0385,  ..., -1.2959, -0.9292, -0.4803],
#           [-1.1903, -1.5667, -1.6939,  ..., -1.2559, -0.8198, -0.5328],
#           ...,
#           [-0.9241, -1.1200, -2.1126,  ..., -1.3768, -0.8534, -0.5285],
#           [-0.9514, -1.1773, -1.7918,  ..., -0.9096, -0.7375, -0.5695],
#           [-0.5593, -0.7322, -0.8121,  ..., -0.3285, -0.2189, -0.3459]],
#
#          [[-0.3845, -0.4775, -0.6565,  ..., -1.0265, -0.9516, -0.7681],
#           [-0.8151, -1.5439, -1.5712,  ..., -1.4472, -1.5162, -0.8418],
#           [-0.7558, -1.0708, -1.1003,  ..., -1.0613, -1.5662, -0.4609],
#           ...,
#           [-1.1411, -1.9395, -1.8951,  ..., -1.7452, -1.6365, -0.7782],
#           [-0.8595, -1.6069, -1.4429,  ..., -1.4950, -1.4983, -0.6253],
#           [-0.8240, -1.3904, -0.9825,  ..., -1.0802, -1.1121, -0.5901]],
#
#          [[-0.6809, -1.5884, -1.4192,  ..., -1.1917, -1.3754, -0.9317],
#           [-0.7405, -1.7491, -1.5343,  ..., -0.8730, -0.9498, -0.8616],
#           [-0.8097, -1.7029, -1.4550,  ..., -0.8951, -1.0813, -0.9067],
#           ...,
#           [-1.7718, -1.5207, -1.0031,  ..., -0.9617, -0.9011, -0.4255],
#           [-1.7198, -1.4293, -0.8512,  ..., -1.0192, -0.8150, -0.4661],
#           [-1.0051, -0.8531, -0.5489,  ..., -0.7467, -0.5444, -0.4207]],
#
#          [[ 0.0224, -0.4879, -0.4170,  ..., -0.2740, -0.6545, -0.4327],
#           [-0.3729, -0.4841, -0.7269,  ..., -0.5088, -0.3775, -0.3726],
#           [-1.0615, -1.3108, -1.0066,  ..., -1.0880, -0.8390, -0.6256],
#           ...,
#           [-0.1849, -1.2661, -1.1239,  ...,  1.3297,  0.7199,  0.5685],
#           [-0.0426, -0.8219, -0.5074,  ...,  0.9209,  0.3183,  0.3275],
#           [-0.0774, -0.1273, -0.2536,  ...,  0.6716,  0.4779,  0.1974]]]])
# Class with the largest presence: Non-plant area
# Non-plant area: 45.35%
# Healthy Plants: 34.44%
# Early Botrytis (Stage 1): 9.68%
# Advanced Botrytis (Stage 2): 0.00%
# Non-reverse Botrytis (Stage 3): 0.02%
# Nutritional Deficiencies: 10.51%

# %% [markdown]
# ## FIN DEL ENTRENAMIENTO

# %% [markdown]
# ##  PYTORCH
